# %% [markdown]
# # Gensim example
#
# * The [gensim tutorial](http://radimrehurek.com/gensim/tut1.html) shows you many ways of doing things...and gives reasons and explanations.
# * This notebook gives a step-by-step cookbook that will work if have a directory structure with flat files
#   * Use IPython's object introspection and help displays to learn about the objects created
#   * The custom classes are located in the `declass` repo, so you can also look at the source code.

# %% [markdown]
# ---
#
# ## Set up
#
# ---

# %%
import os

import pandas as pd
import matplotlib.pylab as plt

from gensim import corpora, models, similarities
import gensim

from jrl_utils.src import nlp
from declass.utils import text_processors, filefilter, gensim_helpers

# %%
# Every time you change the source code you need to reload it
reload(text_processors)
reload(filefilter)
reload(gensim_helpers)
# Out:
# <module 'declass.utils.gensim_helpers' from '/Users/danielkrasner/JRL/declass/declass/utils/gensim_helpers.pyc'>

# %%
# Set paths         
# I use environment variables to set my base paths
DATA = os.environ['DATA']                                                                 
ME = os.environ['ME']                                                                     
MYDATA = os.path.join(DATA, ME, 'ddrs-01')                                           
RAW = os.path.join(MYDATA, 'raw')                                                         
PROCESSED = os.path.join(MYDATA, 'processed')

# You only need to set these paths below...any way you can
metafile_path = os.path.join(RAW, 'ddrs_meta.csv')
text_base_path = os.path.join(RAW, 'ddrs')
corpus_path = os.path.join(PROCESSED, 'corpus', 'ddrs-gensim.svmlight')

# %% [markdown]
# ---
#
# ## Making a dictionary and a corpus
#
# * In gensim, a *dictionary* stores the mapping between strings (e.g. the words in text) and their integer representation (tokenid).  This can be accessed via `dictionary.token2id`.  It also has a function `doc2bow` that transforms tokens to a *bag of words*.
# * In gensim, a *bag of words* is a list of tuples $$[(tokenid_1, value_1),...,(tokenid_k, value_k)]$$ where $tokenid_j$ is an integer, and $value_k$ is a real number.
# * In gensim, a *corpus* is an [iterable](http://stackoverflow.com/questions/9884132/understanding-pythons-iterator-iterable-and-iteration-protocols-what-exact) over *bag of words* representations of documents.
#
# ---

# %%
# Limit analysis to these lines of the corpus.  This is very useful for learning.
# Set == None for no limit.  Set to 5000 to finish in a reasonable amount of time.
limit = 2000

# %%
# The tokenizer turns strings of text such as "hi bye" into lists of tokens, e.g. ['hi', 'bye']
# You can add your own tokenizers to text_processors.  Give them the same API as TokenizerBasic.
tokenizer = text_processors.TokenizerBasic()

# %%
# Define a TokenStreamer over a set of paths
# token_stream will read text from each path and return tokens
path_iter = filefilter.get_paths(text_base_path, get_iter=True)
token_stream = text_processors.TokenStreamer(tokenizer, paths=path_iter, limit=limit)

# %%
# Convert the token stream into a dictionary
# Note that nothing was read from disk until this point!  
# Previously, we had simply defined iterators over files, 
# but we only here do we tell the iterators to start their iterations.
dictionary = corpora.Dictionary(token_stream)
print dictionary
# Out:
# Dictionary(24537 unique tokens)

# %%
dictionary.dfs?

# %%
# Filter extreme words using the built-in method filter_extremes()
dictionary.filter_extremes()

# You can also do a custom filter, e.g.
# Remove some words that occur less than 5 times from dict:
low_freq_ids = [tokenid for tokenid, docfreq in dictionary.dfs.iteritems() if docfreq < 5]
dictionary.filter_tokens(low_freq_ids)

# %%
# Compactify and save to disk
# ALWAYS compactify since this removes gaps and allows for a decent matrix representation (useful later)
dictionary.compactify()
dictionary.save(os.path.join(PROCESSED, 'dict', 'ddrs.dict'))
print dictionary
# Out:
# Dictionary(5952 unique tokens)

# %%
# Create and then serialize (save to disk in a compact format) a corpus
corpus = gensim_helpers.TextFilesCorpus(tokenizer, dictionary, base_path=text_base_path, limit=limit)
corpora.SvmLightCorpus.serialize(corpus_path, corpus)

# %% [markdown]
# ## Do some EDA on the dictionary
#
# * You could also modify the dictionary here

# %%
id2token = dict(dictionary.items())  # dictionary.id2token is not populated by default!!!
words = pd.DataFrame(
                {id2token[tokenid]: [tokenid, docfreq] 
                 for tokenid, docfreq in dictionary.dfs.iteritems()},
                index=['tokenid', 'docfreq']).T

# %%
words = words.sort_index(by='docfreq', ascending=False)
words.head()
# Out:
#              tokenid  docfreq
# secret          3956      828
# one              534      541
# information      835      481
# two             3763      464
# used            2510      463

# %%
# Log plot of distribution shows rapidly decaying tail
words.docfreq.apply(np.log10).hist(bins=200)

# %% [markdown]
# ## Simple topic modeling

# %%
# Load the corpus from disk 
# You should start all analysis with this step
corpus = corpora.SvmLightCorpus(corpus_path)

# %% [markdown]
# ## LSI

# %%
lsi = models.LsiModel(corpus, id2word=dictionary, num_topics=2)

# %%
lsi.print_topics(2)
# Out:
# ['0.161*"soviet" + 0.153*"forces" + 0.153*"military" + 0.153*"units" + 0.150*"army" + 0.149*"secret" + 0.142*"control" + 0.138*"chinese" + 0.135*"general" + 0.131*"north"',
#  '-0.257*"fnu" + -0.255*"formerly" + -0.237*"missile" + 0.180*"chinese" + 0.177*"china" + 0.173*"government" + -0.171*"ing" + -0.167*"engineer" + 0.149*"communist" + -0.148*"secret"']

# %% [markdown]
# ## LDA

# %%
num_words = len(dictionary.items())

# %%
# Standard settings
alpha = None # same as alpha = 1
eta = None  # same as eta = 1
num_topics = 100

# %%
# Screwball alpha setting
# pdf(topic) is peaked near 1 for topic 0, and uniform in topics 1 to 4
# ...so topic 1 is the most likely topic.  See the histogram of df_corpus below
alpha = [10, 1, 1, 1, 1]
eta = None

# %%
# Screwball eta setting
# pdf(word | topic) is peaked near 1 for word 0, and near 0 for the other words
# so word 0 is the most likely word.  You can find "word 0" using dictionary.id2token[0] 
# See the topic printout below and you should find that word 0 is in every topic!
alpha = None
eta = np.r_[1000, 0.1 * np.ones(num_words - 1)]

# %%
dictionary.id2token[0]
# Out:
# 'tdcs'

# %%
# Train the LDA model
lda = models.LdaModel(corpus, id2word=dictionary, num_topics=num_topics, passes=1, alpha=alpha, eta=eta, chunksize=4000)

# %%
# Print the top 6 words for every topic
for i in range(num_topics):
    print
    print "topic", i
    print lda.print_topic(i, topn=6)
# Out:
# topic 0
# 0.014*air + 0.009*fuze + 0.009*china + 0.008*forces + 0.007*well + 0.006*officer
#
# topic 1
# 0.009*soviet + 0.007*secret + 0.006*missile + 0.005*one + 0.005*north + 0.005*army
#
# topic 2
# 0.007*missile + 0.007*secret + 0.006*missiles + 0.006*used + 0.006*soviet + 0.005*such
#
# topic 3
# 0.013*chinese + 0.008*secret + 0.007*intelligence + 0.006*forces + 0.006*military + 0.005*china
#
# topic 4
# 0.007*secret + 0.007*training + 0.006*system + 0.005*soviet + 0.005*missile + 0.005*military
#
# topic 5
# 0.009*forces + 0.006*general + 0.006*army + 0.005*units + 0.005*two + 0.005*fuze
#
# topic 6
# 0.010*secret + 0.006*un + 0.005*berlin + 0.005*information + 0.005*security + 0.004*during
#
# topic 7
# 0.010*army + 0.010*north + 0.010*soviet + 0.010*units + 0.008*forces + 0.007*security
#
# topic 8
# 0.008*enemy + 0.008*secret + 0.007*soviet + 0.007*forces + 0.006*general + 0.006*plat
#
# topic 9
# 0.012*engineer + 0.012*formerly + 0.008*ing + 0.008*located + 0.007*fnu + 0.007*equipment
#
# topic 10
# 0.009*secret + 0.008*government + 0.007*security + 0.005*chinese + 0.005*china + 0.005*information
#
# topic 11
# 0.013*general + 0.012*staff + 0.008*command + 0.008*army + 0.007*fuze + 0.007*department
#
# topic 12
# 0.011*fuze + 0.006*remove + 0.006*spring + 0.006*confidential + 0.006*mine + 0.005*vol
#
# topic 13
# 0.019*fnu + 0.008*ing + 0.008*chinese + 0.008*engineer + 0.007*formerly + 0.007*secret
#
# topic 14
# 0.009*weapons + 0.009*soviet + 0.005*china + 0.005*korean + 0.005*testing + 0.004*army
#
# topic 15
# 0.008*hq + 0.007*secret + 0.005*army + 0.005*objects + 0.005*during + 0.005*forces
#
# topic 16
# 0.009*hq + 0.008*training + 0.007*source + 0.006*secret + 0.005*tons + 0.004*eusak
#
# topic 17
# 0.014*training + 0.008*enemy + 0.007*security + 0.006*secret + 0.006*attack + 0.006*each
#
# topic 18
# 0.010*gen + 0.010*fnu + 0.008*government + 0.008*secret + 0.006*communist + 0.006*formerly
#
# topic 19
# 0.007*production + 0.006*fuze + 0.006*china + 0.006*secret + 0.005*government + 0.005*assembly
#
# topic 20
# 0.007*soviet + 0.006*fnu + 0.006*mine + 0.006*confidential + 0.006*formerly + 0.005*army
#
# topic 21
# 0.011*secret + 0.011*enemy + 0.010*fuze + 0.009*security + 0.009*information + 0.007*forces
#
# topic 22
# 0.006*two + 0.006*secret + 0.005*missile + 0.005*united + 0.005*mines + 0.005*forces
#
# topic 23
# 0.013*control + 0.006*confidential + 0.006*section + 0.006*missile + 0.005*enemy + 0.005*system
#
# topic 24
# 0.008*company + 0.008*fnu + 0.007*engineer + 0.007*ccf + 0.007*tn + 0.006*units
#
# topic 25
# 0.011*mine + 0.008*secret + 0.008*information + 0.007*fuze + 0.006*security + 0.006*confidential
#
# topic 26
# 0.005*united + 0.005*used + 0.005*forces + 0.005*military + 0.005*enemy + 0.005*population
#
# topic 27
# 0.015*secret + 0.011*information + 0.009*missile + 0.008*security + 0.005*lbs + 0.005*ft
#
# topic 28
# 0.011*communist + 0.006*one + 0.006*control + 0.005*soviet + 0.005*secret + 0.005*missile
#
# topic 29
# 0.011*government + 0.010*china + 0.008*national + 0.006*communist + 0.006*secret + 0.005*fuze
#
# topic 30
# 0.010*china + 0.007*military + 0.007*chinese + 0.006*secret + 0.006*political + 0.006*government
#
# topic 31
# 0.020*figure + 0.009*gun + 0.009*fuze + 0.008*mine + 0.007*soviet + 0.006*control
#
# topic 32
# 0.009*ccf + 0.009*training + 0.008*military + 0.007*soviet + 0.006*secret + 0.005*north
#
# topic 33
# 0.009*control + 0.008*equipment + 0.007*soviet + 0.007*government + 0.007*communist + 0.006*supply
#
# topic 34
# 0.009*formerly + 0.007*fnu + 0.007*secret + 0.007*engineer + 0.007*ing + 0.006*control
#
# topic 35
# 0.010*forces + 0.008*enemy + 0.006*communist + 0.006*secret + 0.006*military + 0.005*intelligence
#
# topic 36
# 0.007*secret + 0.007*forces + 0.007*enemy + 0.006*units + 0.005*artillery + 0.005*used
#
# topic 37
# 0.007*military + 0.007*staff + 0.006*general + 0.006*army + 0.006*control + 0.005*soviet
#
# topic 38
# 0.014*mine + 0.012*party + 0.010*government + 0.010*communist + 0.007*secret + 0.007*china
#
# topic 39
# 0.018*hq + 0.012*eusak + 0.008*secret + 0.008*combat + 0.006*inf + 0.006*ccf
#
# topic 40
# 0.010*missile + 0.009*soviet + 0.007*fuze + 0.006*army + 0.006*figure + 0.006*training
#
# topic 41
# 0.009*secret + 0.007*control + 0.006*soviet + 0.006*source + 0.006*missile + 0.006*production
#
# topic 42
# 0.008*secret + 0.006*control + 0.005*fnu + 0.005*test + 0.005*chinese + 0.005*national
#
# topic 43
# 0.007*united + 0.007*fire + 0.006*platoon + 0.006*weapons + 0.006*secret + 0.006*positions
#
# topic 44
# 0.012*enemy + 0.008*fuze + 0.007*army + 0.006*forces + 0.006*confidential + 0.006*air
#
# topic 45
# 0.016*vol + 0.016*confidential + 0.015*fuze + 0.009*striker + 0.008*tm + 0.008*april
#
# topic 46
# 0.014*artillery + 0.009*soviet + 0.008*north + 0.007*korean + 0.007*enemy + 0.006*support
#
# topic 47
# 0.006*range + 0.005*fnu + 0.005*formerly + 0.005*used + 0.005*chinese + 0.005*located
# topic 48
# 0.007*pressure + 0.006*fuze + 0.006*mine + 0.006*artillery + 0.006*one + 0.005*units
#
# topic 49
# 0.013*formerly + 0.007*secret + 0.006*fnu + 0.006*germany + 0.005*chinese + 0.005*general
#
# topic 50
# 0.013*enemy + 0.009*forces + 0.006*one + 0.006*secret + 0.006*confidential + 0.005*hq
#
# topic 51
# 0.011*equipment + 0.008*units + 0.006*hq + 0.006*confidential + 0.006*chinese + 0.005*information
#
# topic 52
# 0.008*secret + 0.005*confidential + 0.005*factory + 0.004*during + 0.004*government + 0.004*units
#
# topic 53
# 0.009*percent + 0.008*secret + 0.008*army + 0.007*fnu + 0.007*communist + 0.005*last
#
# topic 54
# 0.010*formerly + 0.008*fnu + 0.007*mine + 0.006*government + 0.006*secret + 0.006*reported
#
# topic 55
# 0.010*equipment + 0.008*co + 0.007*op + 0.007*bn + 0.006*used + 0.006*mm
#
# topic 56
# 0.013*china + 0.008*north + 0.005*chinese + 0.005*west + 0.005*forces + 0.005*national
#
# topic 57
# 0.009*forces + 0.007*hq + 0.007*staff + 0.007*units + 0.007*army + 0.006*command
#
# topic 58
# 0.014*forces + 0.007*soviet + 0.006*weapons + 0.005*army + 0.005*secret + 0.005*communist
#
# topic 59
# 0.022*formerly + 0.016*fnu + 0.012*ing + 0.012*engineer + 0.009*russia + 0.008*secret
#
# topic 60
# 0.010*soviet + 0.009*weapons + 0.009*chinese + 0.006*china + 0.006*figure + 0.005*equipment
#
# topic 61
# 0.013*secret + 0.012*security + 0.009*fnu + 0.007*formerly + 0.006*missile + 0.005*control
#
# topic 62
# 0.015*government + 0.008*china + 0.008*national + 0.008*party + 0.007*secret + 0.006*chinese
#
# topic 63
# 0.009*china + 0.008*government + 0.008*communist + 0.006*chinese + 0.006*secret + 0.006*national
#
# topic 64
# 0.007*section + 0.007*military + 0.006*army + 0.006*ii + 0.006*percent + 0.006*total
#
# topic 65
# 0.011*feet + 0.008*secret + 0.007*enemy + 0.006*artillery + 0.005*line + 0.005*security
#
# topic 66
# 0.008*secret + 0.007*missile + 0.006*political + 0.006*missiles + 0.006*equipment + 0.006*control
#
# topic 67
# 0.010*fnu + 0.006*military + 0.006*guerrilla + 0.006*korean + 0.006*secret + 0.006*china
#
# topic 68
# 0.011*striker + 0.011*confidential + 0.008*vol + 0.007*pin + 0.006*charge + 0.006*fuze
#
# topic 69
# 0.013*formerly + 0.013*missile + 0.012*fnu + 0.011*engineer + 0.009*ing + 0.008*secret
#
# topic 70
# 0.010*institute + 0.007*soviet + 0.007*reported + 0.006*government + 0.006*figure + 0.006*one
#
# topic 71
# 0.008*states + 0.007*confidential + 0.007*united + 0.006*japan + 0.006*mine + 0.006*jcs
#
# topic 72
# 0.009*enemy + 0.007*during + 0.006*rate + 0.006*attack + 0.006*laos + 0.005*units
#
# topic 73
# 0.009*secret + 0.009*general + 0.008*united + 0.008*fnu + 0.007*artillery + 0.007*security
#
# topic 74
# 0.009*one + 0.008*information + 0.007*enemy + 0.007*forces + 0.006*factory + 0.006*security
#
# topic 75
# 0.008*secret + 0.006*fnu + 0.006*dr + 0.005*missile + 0.005*formerly + 0.005*one
#
# topic 76
# 0.016*gun + 0.010*hq + 0.008*section + 0.008*intelligence + 0.007*machine + 0.007*forces
#
# topic 77
# 0.014*mine + 0.006*chinese + 0.006*fuze + 0.006*secret + 0.006*artillery + 0.005*confidential
#
# topic 78
# 0.021*fuze + 0.012*vol + 0.011*confidential + 0.009*mine + 0.008*detonator + 0.007*remove
#
# topic 79
# 0.011*enemy + 0.009*china + 0.008*secret + 0.006*party + 0.005*production + 0.005*information
#
# topic 80
# 0.012*fuze + 0.010*mine + 0.007*pin + 0.006*striker + 0.006*chinese + 0.005*used
#
# topic 81
# 0.007*communist + 0.007*secret + 0.006*party + 0.005*government + 0.005*missile + 0.005*time
#
# topic 82
# 0.007*information + 0.007*one + 0.005*soviet + 0.005*secret + 0.005*control + 0.005*missile
#
# topic 83
# 0.008*secret + 0.008*training + 0.007*missile + 0.007*soviet + 0.006*china + 0.005*equipment
#
# topic 84
# 0.007*soviet + 0.007*source + 0.007*information + 0.006*equipment + 0.006*company + 0.006*confidential
#
# topic 85
# 0.007*supply + 0.006*equipment + 0.006*army + 0.005*units + 0.005*china + 0.005*group
#
# topic 86
# 0.014*china + 0.008*chinese + 0.007*communist + 0.006*government + 0.005*secret + 0.005*national
#
# topic 87
# 0.012*fuze + 0.007*military + 0.005*mine + 0.004*equipment + 0.004*communist + 0.004*pressure
#
# topic 88
# 0.008*secret + 0.008*security + 0.007*united + 0.007*two + 0.006*general + 0.006*information
#
# topic 89
# 0.015*chinese + 0.008*china + 0.007*army + 0.006*security + 0.006*one + 0.006*fire
#
# topic 90
# 0.009*army + 0.009*secret + 0.008*information + 0.007*one + 0.006*security + 0.006*confidential
#
# topic 91
# 0.011*soviet + 0.008*party + 0.008*range + 0.006*artillery + 0.005*missile + 0.005*confidential
#
# topic 92
# 0.007*secret + 0.006*assembly + 0.006*pin + 0.006*air + 0.005*missile + 0.005*feet
#
# topic 93
# 0.008*equipment + 0.007*soviet + 0.007*units + 0.007*fnu + 0.007*formerly + 0.005*reported
# topic 94
# 0.006*phoenix + 0.006*members + 0.005*liberation + 0.005*fo + 0.005*source + 0.005*vc
#
# topic 95
# 0.011*equipment + 0.008*secret + 0.006*weapons + 0.005*enemy + 0.005*training + 0.005*control
#
# topic 96
# 0.012*secret + 0.009*fnu + 0.005*formerly + 0.005*forces + 0.005*german + 0.005*used
#
# topic 97
# 0.016*training + 0.011*communist + 0.010*forces + 0.007*army + 0.007*military + 0.006*secret
#
# topic 98
# 0.007*hq + 0.007*enemy + 0.007*secret + 0.006*air + 0.006*information + 0.005*force
#
# topic 99
# 0.007*secret + 0.007*during + 0.006*soviet + 0.006*security + 0.005*control + 0.005*military

# %%
# Print the topic distribution for the first document in the corpus
one_doc = corpus.docbyoffset(corpus.index[0])
vec_lda = lda[one_doc]
print vec_lda
# Out:
# []

# %%
# Store the topic score for every doc in the corpus
df_corpus = pd.concat([pd.Series(dict(doc)) for doc in lda[corpus]], axis=1).fillna(0).T

# %%
# Look at histograms of each topic over the corpus
fig = df_corpus.hist()

# %%
# Look at similarity between one_doc and all the other docs in the corpus
# MatrixSimilarity uses a regular matrix...not good for memory
# See http://radimrehurek.com/gensim/tut3.html  for different similarity matrix types (e.g. sparse)
#
# Of course this doc is most similar (score = 1) with itself.
index = similarities.MatrixSimilarity(lda[corpus])
doc_zero = corpus.docbyoffset(corpus.index[0])
sims = index[lda[doc_zero]]
print sims[:5]
# Out:
# [ 1.          0.62181062  0.65315092  0.81168163  0.        ]

# %%
# Compare a new doc to the existing docs
# This time, store the similarity in a pandas Series for easy plotting
new_doc = dictionary.doc2bow(['hello', 'my', 'name', 'is', 'richard', 'nixon'])
new_doc_sims = pd.Series(index[lda[new_doc]])
fig = new_doc_sims.hist()

# %% [markdown]
# ---
#
# # Performance considerations
#
# * Walking through a directory structure and tokenizing every file is slow
#   * You can tokenize once (quickly) and then re-load these tokens
#
# * LDA is slow
#   * Not sure what to do...I am linked against MKL...maybe VW is the only way
#
# ---

# %% [markdown]
# ### Quick parallel tokenization
#
# Use the command line utility `cmd/files_to_vw.py` to tokenize and save to a sparse format.  Use the `n_jobs` option to do this in parallel.  Note that this utility requires the [parallel_easy](https://github.com/langmore/parallel_easy) library.

# %% [markdown]
# ### Quick (VW) corpus streaming
#
# 1. Use `VWFormatter.sfile_to_token_iter()` to convert the sparse files to a stream of token lists.
# 2. Convert this stream to a dictionary
# 3. Modify the dictionary if necessary
# 4. Create the stream once again
# 5. Serialize into the sparse SvmLightCorpus
#
# Note that we store the original corpus in VW format since this is much richer than SvmLight.  In particular, you can use actual strings to save the tokens, rather than tokenid (as required by SvmLight).

# %%
vw_corpus_path = os.path.join(PROCESSED, 'corpus', 'ddrs-vw')

# %%
# Build a dictionary from a sparse (VW) representation of a corpus
# About 2x faster than tokenizing on the fly using the BasicTokenizer
# Even faster if your tokenizer is slow
token_stream = text_processors.VWFormatter().sfile_to_token_iter(vw_corpus_path)
dictionary = corpora.Dictionary(token_stream)

# %%
# Note:  This interface is experimental
token_stream = text_processors.VWFormatter().sfile_to_token_iter(vw_corpus_path)

class MyCorpus(object):
    """
    A simple corpus built with a dictionary and a token stream. 
    """
    def __init__(self, dictionary, token_stream):
        self.token_stream = token_stream
        self.dictionary = dictionary
    
    def __iter__(self):
        """
        This method returns an iterator.
        This method is automatically called when you use MyCorpus in a for loop.  The returned value becomes the loop iterator.
        """
        for token_list in token_stream:
            yield self.dictionary.doc2bow(token_list)

# %timeit -n1 -r1 corpora.SvmLightCorpus.serialize(corpus_path, MyCorpus(dictionary, token_stream))
# Out:
# 1 loops, best of 1: 5min 52s per loop

# %% [markdown]
# ## Similarities
# * Refer to [similarity doc](http://radimrehurek.com/gensim/similarities/docsim.html) for more infomration

# %%
#In case you have not run the above this session, load the dictionary and corpus from disk
dictionary = corpora.Dictionary.load(os.path.join(PROCESSED, 'dict', 'ddrs.dict'))
corpus = corpora.SvmLightCorpus(corpus_path)

# %%
#first define an LSI space, with 2 topics
lsi = models.LsiModel(corpus, id2word=dictionary, num_topics=2)
lsi.print_topics(2)

# %%
#pick a query or phrase and find how similar it is to the lsi topic 
query = 'Cold war threat'
vec_bow = dictionary.doc2bow(query.lower().split())

# %%
vec_lsi = lsi[vec_bow] # convert the query to LSI space

# %%
print query
print vec_lsi
print lsi.print_topics(2) # it makes sense that the query is closer to topic 1 than 2
# Out:
# Cold war threat
# [(0, 0.1058455024343392), (1, 0.036158438494315805)]
# ['0.161*"soviet" + 0.153*"forces" + 0.153*"military" + 0.153*"units" + 0.150*"army" + 0.149*"secret" + 0.142*"control" + 0.138*"chinese" + 0.135*"general" + 0.131*"north"', '-0.257*"fnu" + -0.255*"formerly" + -0.237*"missile" + 0.180*"chinese" + 0.177*"china" + 0.173*"government" + -0.171*"ing" + -0.167*"engineer" + 0.149*"communist" + -0.148*"secret"']

# %%
# transform corpus to LSI space and index it
index = similarities.MatrixSimilarity(lsi[corpus]) 
index.save(os.path.join(PROCESSED, 'sim_index','ddrs_sim.index'))

# %% [markdown]
# ###note:
#     * using similarities.MatrixSimilarity stores the entire matrix in memory
#     * when working with a large set use the similarities.Similarity method which shards the index (uses similarities.MatrixSimilarity
#     and similarities.SparseMatrixSimilarity internally)

# %%
###if starting here, load the sim index from file
index = similarities.MatrixSimilarity.load(os.path.join(PROCESSED, 'sim_index','ddrs_sim.index'))

# %%
# lets look at similaries to our query
sims = index[vec_lsi]
sims = sorted(enumerate(sims), key=lambda item: -item[1]) # put into descending order if you like
# print doc index and it's similarity score
print list(enumerate(sims))[:10]
# Out:
# [(0, (1246, 0.99999994)), (1, (9, 0.99999911)), (2, (1847, 0.99999863)), (3, (1900, 0.99999863)), (4, (1468, 0.99999785)), (5, (1801, 0.9999969)), (6, (1826, 0.99999678)), (7, (1795, 0.99999583)), (8, (1807, 0.99999309)), (9, (1929, 0.9999904))]

# %%
#look at the sim distribution
pd.Series(sims).hist(bins=40, figsize=(15,5))

# %%
#retrieve all documents with similary score > .95
high_sims = [(i, score) for i, score in enumerate(sims) if score >.95]
high_sims
# Out:
# [(1, 0.99957252),
#  (2, 0.99637115),
#  (4, 0.99430466),
#  (5, 0.96128106),
#  (6, 0.99676079),
#  (7, 0.99773276),
#  (9, 0.99999911),
#  (10, 0.96443456),
#  (11, 0.96591181),
#  (14, 0.99048162),
#  (15, 0.99660909),
#  (16, 0.99739939),
#  (17, 0.99577338),
#  (18, 0.99995691),
#  (20, 0.99831194),
#  (21, 0.96833807),
#  (23, 0.99340355),
#  (27, 0.98083007),
#  (28, 0.99812263),
#  (29, 0.99582803),
#  (30, 0.99938995),
#  (31, 0.99301887),
#  (32, 0.9969914),
#  (33, 0.9878282),
#  (34, 0.98797464),
#  (35, 0.99296546),
#  (36, 0.99718726),
#  (37, 0.99090499),
#  (38, 0.99550849),
#  (39, 0.99354875),
#  (40, 0.97309422),
#  (41, 0.98527104),
#  (42, 0.98275214),
#  (43, 0.97512287),
#  (44, 0.98632759),
#  (45, 0.97052056),
#  (46, 0.96553373),
#  (47, 0.99183553),
#  (48, 0.97165263),
#  (49, 0.99277788),
#  (50, 0.95458108),
#  (51, 0.99883467),
#  (52, 0.98829198),
#  (53, 0.99978924),
#  (54, 0.99867165),
#  (55, 0.99829507),
#  (56, 0.99744368),
#  (57, 0.99440217),
#  (58, 0.98950428),
#  (59, 0.98552126),
#  (60, 0.99983728),
#  (61, 0.97686702),
#  (62, 0.96168268),
#  (65, 0.95041531),
#  (75, 0.95116132),
#  (76, 0.96208423),
#  (81, 0.96308845),
#  (82, 0.99919474),
#  (83, 0.99273407),
#  (84, 0.98581004),
#  (85, 0.9966473),
#  (86, 0.95496511),
#  (87, 0.99063486),
#  (88, 0.982252),
#  (89, 0.99224269),
#  (90, 0.97046232),
#  (91, 0.99823266),
#  (93, 0.98233217),
#  (94, 0.98947537),
#  (95, 0.977337),
#  (96, 0.98210973),
#  (98, 0.99533242),
#  (99, 0.96651804),
#  (101, 0.98356354),
#  (102, 0.99774158),
#  (103, 0.95094943),
#  (104, 0.9592973),
#  (106, 0.97242796),
#  (107, 0.99021113),
#  (110, 0.95267642),
#  (112, 0.9689244),
#  (113, 0.98619616),
#  (115, 0.9548865),
#  (117, 0.99921906),
#  (120, 0.97252333),
#  (121, 0.95130914),
#  (124, 0.96141958),
#  (1898, 0.99799371),
#  (1899, 0.99892008),
#  (1900, 0.99999863),
#  (1901, 0.99472558),
#  (1902, 0.98923814),
#  (1903, 0.99914366),
#  (1904, 0.99969125),
#  (1905, 0.99377155),
#  (1906, 0.99927598),
#  (1907, 0.99916399),
#  (1908, 0.99746293),
#  (1909, 0.97203773),
#  (1910, 0.99946749),
#  (1911, 0.99970305),
#  (1912, 0.99405372),
#  (1913, 0.99978781),
#  (1914, 0.99881369),
#  (1915, 0.98812836),
#  (1916, 0.9882341),
#  (1917, 0.99481803),
#  (1919, 0.96999073),
#  (1920, 0.99991894),
#  (1922, 0.99315202),
#  (1923, 0.99873126),
#  (1924, 0.96708524),
#  (1925, 0.99485183),
#  (1926, 0.99545133),
#  (1927, 0.99904644),
#  (1928, 0.99820352),
#  (1929, 0.9999904),
#  (1930, 0.99978381),
#  (1931, 0.96563756),
#  (1932, 0.99001539),
#  (1934, 0.9760083),
#  (1935, 0.97335494),
#  (1936, 0.96075869),
#  (1938, 0.95677435),
#  (1940, 0.99594873),
#  (1941, 0.99843472),
#  (1942, 0.9968214),
#  (1943, 0.9603008),
#  (1944, 0.99608886),
#  (1945, 0.98386347),
#  (1946, 0.98023993),
#  (1949, 0.99932957),
#  (1950, 0.99007994),
#  (1952, 0.9814536),
#  (1953, 0.98822784),
#  (1955, 0.95848519),
#  (1959, 0.99563211),
#  (1960, 0.98807722),
#  (1961, 0.99479723),
#  (1962, 0.99992067),
#  (1963, 0.99894488),
#  (1964, 0.98746687),
#  (1966, 0.98886323),
#  (1968, 0.99252063),
#  (1970, 0.99791372),
#  (1974, 0.9888947),
#  (1975, 0.9999336),
#  (1977, 0.99949366),
#  (1981, 0.99985361),
#  (1986, 0.99552715),
#  (1988, 0.9601751),
#  (1989, 0.99256188),
#  (1992, 0.99993593),
#  (1993, 0.99552035),
#  (1997, 0.99909949),
#  (1999, 0.98939645)]

# %%
#lets actually look a a few of these docs
path_iter = filefilter.get_paths(text_base_path, get_iter=True)
texts = []
i = 0
for path in path_iter:
    with open(path) as f:
        text = f.read()
        texts.append(text)
        i+=1
        if i==5: break
#print texts
# Out:
# ['  \n', "  \n  \n  PP WTES \n  DE WTE 2 \n  Received \n  252316 \n  Z \n  DE ESI \n  P 25225332 \n  FM DIRECTOR CIA \n  TO WHITE HOUSE \n  PASS PRESIDENTIAL PARTY, AT HYANNISPORT, ATTENTION COL. MC HUGH, \n  FOR DELIVERY TO PRESIDENT KENNEDY \n  FOLLOWING MEMORANDUM ON QUADROS\\' RESIGNATION PREPARED BY CIA: \n  \n 1. QUADROS\\' ATTENTIONS TO THE CHE GUEVARA AND GAGARIN, AND \n  MORE GENERALLY HIS MANIFEST TENDENCIES TO DRAW CLOSER TO THE \n  BLOC, HAVE AROUSED STRONG EXPRESSIONS OF DISAPPROVAL FROM THE \n  ARMY AND FROM CONSERVATIVE ELEMENTS IN BRAZIL. WE THINK IT \n  LIKELY THAT HE RESIGNED IN THE EXPECTATION OF PROVOKING A STRONG \n  MANIFESTATION OF POPULAR SUPPORT, IN RESPONSE TO WHICH HE WOULD \n  PAGE 1 \n   *FOOTER*  \n  2 \n  Received \n  252316 Z \n  CONFIDENTIAL \n  Declassified by \n  date 27 NOV 1975 \n  \n  \n  \n  \n", '  \n  \n  PAGE TWO WTE 2 \n  RETURN TO OFFICE IN A BETTER POSITION AGAINST HIS OPPONENTS. \n  (FIDEL CASTRO RESIGNED ONCE FOR THIS PURPOSE, AND PERON MORE THAN \n  ONCE). ALTHOUGH THE HIGHER RANKS OF THE ARMY DISLIKE QUADROS, \n  THEY WOULD IROBABLY NOT BLOCK. HIS RETURN IN SUCH CIRCUMSTANCES. \n  \n 2. IF QUADROS DOES NOT COME BACK, WE BELIEVE, THAT THE NEXT \n  GOVERNMENT WILL FOLLOW CONSERVATIVE THOUGH NATIONALIST POLICIES, \n  BECAUSE THE ARMY WILL NOT TOLERATE ANYTHING ELSE. \n  \n 3. VICE PRESIDENT GOULART, THE CONSTITUTIONAL SUCCESSOR, HAD \n  JUST LEFT BY SEA FROM COMMUNIST CHINA, AND WILL, NOT BE ON HAND FOR \n  AT LEAST A FEW DAYS. HE IS STRONGLY LEFTIST, AND THE ARMY, WOULD \n  BE UNL IKELY TO ALLOW HIM TO EXERT REAL CONTROL OF BRAZILIAN POLICY. \n  \n 4. THE POSSIBILITY OF TROUBLE IN BRAZIL, DUE TO QUADROS\\\' \n  FLIRTATION WITH THE BLOC AND HIS TENDENCY TO HASTY AND DRAMATIC \n  ACTION, HAS BEEN RECOGNIZED FOR SOME TIME; USIB DREW ATTENTION \n  TO IT ON 24 AUGUST, IN A "SURVEY OF COLD WAR CRISIS SITUATIONS", \n  AND IN A NATIONAL INTELLIGENCE ESTIMATE ON 8 AUGUST. \n  \n 1812 1812 \n  25/23032 AUG \n  \n PAGE 2 \n   *FOOTER*  \n  CONFIDENTIAL \n  CONFIDENTIAL \n   \n  \n', '  \n', "  \n  \n  CENTRAL INTELLIGENCE AGENCY \n  WASHINGTON 25. D. C. \n  OFFICE OF THE DIRECTOR \n  28 August 1961 \n  MEMORANDUM \n  SUBJECT: The Situation in Brazil \n  \n 1. The political situation in Brazil has deteriorated rapidly \n  since the resignation of President Quadros on August 25. The \n  causes for the resignation were probably various, and included \n  the peculiar temperament of Quadros himself, who is known for \n  hasty and dramatic moves. \n  \n 2. One contributing factor to Quadros resignation was the \n  public allegation by the Governor of Guanabara (Rio de Janeiro) \n  that Quadros was trying to strengthen his own power at the expense \n  of the legislature. During the preceding week or two, moreover, \n  there had been noticeably increased grumbling about Quadros\\' \n  foreign policy, in particular his flirtation with the Communist bloc. \n  \n  *FOOTER*  \n  SANITIZED COPY \n  \n  \n  \n  \n"]

# %% [markdown]
# ---
#
# # Scratch work
#
# ---

# %%
print dictionary
# Out:
# Dictionary(1461280 unique tokens)

# %%
dictionary.filter_extremes?

# %%
dictionary.filter_extremes(no_below=5, no_above=0.5)

# %%
print dictionary
# Out:
# Dictionary(100000 unique tokens)

# %%
dictionary.filter_extremes(no_above=0.3)

# %%
print dictionary
# Out:
# Dictionary(99997 unique tokens)
